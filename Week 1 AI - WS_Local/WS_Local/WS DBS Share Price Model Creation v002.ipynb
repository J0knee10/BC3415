# %%
import pandas as pd

# %%
df = pd.read_csv("DBS_SingDollar.csv")

# %%
X = df.loc[:,["SGD"]]
Y = df.loc[:,['DBS']]
print(X)

from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X,Y)
pred = model.predict(X)
# Out:
#          SGD
# 0    1.38925
# 1    1.38707
# 2    1.38324
# 3    1.38378
# 4    1.37595
# ..       ...
# 117  1.44655
# 118  1.44814
# 119  1.45018
# 120  1.44954
# 121  1.44766
#
# [122 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(Y,pred)**0.5
print(rmse)
#print(rmse/Y.mean(axis=0)*100)
# Out:
# 0.6283698867042151

# %%
model.coef_
# Out:
# array([[-50.60094302]])

# %%
model.intercept_
# Out:
# array([90.22858515])

# %%
#save model
import joblib
joblib.dump(model,"dbs.jl")
# Out:
# ['dbs.jl']

# %% [markdown]
# ---

# %%
#load model
import joblib
model = joblib.load("dbs.jl")

# Predict 
rate = 1.34
model.predict([[rate]])[0]
# Out:
# /opt/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([22.4233215])

# %% [markdown]
# ### The End, is the New Start.
